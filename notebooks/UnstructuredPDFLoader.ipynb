# %%
# !pip instal unstructured "unstructured[pdf]"

# %%
# !sudo apt-get install tesseract-ocr tesseract-ocr-ita poppler-utils

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = UnstructuredPDFLoader("documento.pdf", mode="elements",
    strategy="hi_res", # or "ocr_only"
    languages="ita")

documents = loader.load() # Questo chiama Unstructured internamente

# Divsion in chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)

chunks = text_splitter.split_documents(documents)

# chunks is going to be EMBEDDED and INDEXED
